# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import string

import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.abs(np.random.randn(50, 8)), columns=list(string.ascii_uppercase[:8]))
df_long = pd.DataFrame(np.abs(np.random.randn(int(1e3), 8)), columns=list(string.ascii_uppercase[:8]))
df_wide = pd.DataFrame(np.abs(np.random.randn(50, 20)), columns=list(string.ascii_uppercase[:20]))

df_categorical = pd.DataFrame({'value': np.random.randint(0, 100, 20)})
labels = ["{0} - {1}".format(i, i + 9) for i in range(0, 100, 10)]

df_categorical['group'] = pd.cut(df_categorical.value, range(0, 105, 10), right=False, labels=labels)

# %% [markdown]
# ---

# %%
df
# Out:
#            A         B         C         D         E         F         G  \
# 0   0.873223  0.199754  1.366818  1.289930  0.360172  1.223327  1.500281
# 1   0.402413  0.829096  0.029545  0.556501  0.206092  0.170426  0.123511
# 2   3.129250  1.865377  0.636216  0.923421  0.756166  0.033339  0.140714
# 3   0.372287  0.335378  0.338970  0.335673  1.960769  0.221301  1.351497
# 4   1.616911  0.213801  1.640558  1.090022  2.261477  1.699372  1.061882
# 5   0.375997  0.803432  0.854846  0.428548  1.320858  0.779195  1.165907
# 6   1.451066  1.175517  1.947153  0.806188  0.583062  2.377768  1.004488
# 7   1.358030  2.369134  0.650103  0.649225  0.513272  0.747490  2.056136
# 8   0.262845  1.193225  1.045893  0.186090  1.858883  0.232628  1.159655
# 9   0.766058  0.595714  1.313557  0.484230  0.699529  0.482368  0.636097
# 10  1.723745  0.208289  0.505785  0.044090  0.712795  0.524906  0.301842
# 11  0.790385  0.096192  0.249185  0.590045  0.164861  0.789825  0.123855
# ...

# %%
df_long
# Out:
#             A         B         C         D         E         F         G  \
# 0    0.246919  1.070343  0.014713  1.196354  0.768793  1.897002  0.891041
# 1    0.811798  0.343642  2.990782  1.680476  0.041208  1.280273  2.033493
# 2    0.281830  1.077395  1.127445  0.175407  0.191342  0.469632  0.450979
# 3    0.536137  0.031254  0.841379  1.227650  0.845826  0.666847  0.803244
# 4    0.302300  0.153300  0.492387  1.268958  1.666946  0.435877  0.434393
# 5    1.622895  1.032433  0.633575  0.663842  0.825861  1.073076  1.118214
# 6    0.702588  0.145921  2.247154  1.823297  1.937636  0.761753  0.703033
# 7    0.742410  1.723685  0.562622  0.984992  0.363795  0.737686  1.612992
# 8    0.356895  0.097018  0.196261  0.145965  0.165575  0.180857  1.007939
# 9    0.586548  0.230459  0.109022  0.817141  0.216450  0.087749  0.576245
# 10   1.642281  0.632342  2.042984  3.143095  1.221965  0.622690  1.274038
# 11   1.349505  0.831226  1.159180  0.495807  0.789705  0.380684  0.937738
# ...

# %%
df_wide
# Out:
#            A         B         C         D         E         F         G  \
# 0   0.930700  0.162067  0.716909  0.314718  1.626716  0.797051  1.482908
# 1   1.860902  0.630622  0.381747  0.653671  0.296737  0.885267  0.000172
# 2   1.385944  1.787292  0.037552  0.980389  1.194353  0.687225  1.030323
# 3   1.292533  0.116568  0.017236  0.750186  0.419033  1.376831  1.363228
# 4   0.854089  0.356368  1.380458  0.190960  0.648790  0.541281  0.302899
# 5   1.941231  0.283774  0.524804  1.299840  1.799890  0.559265  0.748854
# 6   1.319706  0.140008  0.790462  0.617956  0.420322  0.390716  0.522783
# 7   0.199927  1.037032  0.166830  0.840406  0.185698  0.728987  0.625558
# 8   1.053240  0.899834  0.061236  0.848923  2.063525  1.200422  0.470384
# 9   0.467966  0.208248  2.373961  0.278598  0.791633  0.692977  0.767564
# 10  1.964788  1.715898  0.009416  0.366764  0.452230  1.573503  0.081083
# 11  0.194927  0.587299  1.358721  0.769589  0.022865  0.181008  0.394485
# ...

# %%
df_categorical
# Out:
#     value    group
# 0      67  60 - 69
# 1      18  10 - 19
# 2       6    0 - 9
# 3      22  20 - 29
# 4       9    0 - 9
# 5       2    0 - 9
# 6      63  60 - 69
# 7      11  10 - 19
# 8      42  40 - 49
# 9      39  30 - 39
# 10     49  40 - 49
# 11     75  70 - 79
# 12     93  90 - 99
# 13     16  10 - 19
# 14     79  70 - 79
# 15     74  70 - 79
# 16     62  60 - 69
# 17     81  80 - 89
# 18     42  40 - 49
# 19     14  10 - 19

# %% [markdown]
# ---

# %%
from jupyter_datatables import init_datatables_mode

init_datatables_mode()

# %%
df
# Out:
# <div id="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782_length"><label>Show <select name="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782_length" aria-controls="198a24d18ae160670e841ae5ecf474792f4396b5292434a705331e5aecddc782" class="">
# ...

# %%
df_long
# Out:
# <div id="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7_length"><label>Show <select name="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7_length" aria-controls="c88f2a7ec606f60118d08de9ad59cbf4d22994bed4af653e0d994e451df47cd7" class="">
# ...

# %%
df_wide
# Out:
# <div id="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b_length"><label>Show <select name="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b_length" aria-controls="94f7ac6117891d7d4d10018b6cad1519dd4fa8d9e4457213eb15f1674739689b" class="">
# ...

# %%
df_categorical
# Out:
# <div id="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8_length"><label>Show <select name="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8_length" aria-controls="bf4885873d6b286ff495c079b7b790ec746af32a5933ac42a4edec863c41c5e8" class="">
# ...

# %% [markdown]
# ---

# %%
from jupyter_require import execute_with_requirements

from jupyter_datatables import config

options = {}
options.update(config.defaults.options)

# pop buttons, we need to use them separately
buttons = options.pop("buttons", [])
classes = " ".join(config.defaults.classes)

html = df.to_html(classes=classes, table_id='test-table')

script = """
const settings = await append_datatable(`$$html`, $$options, $$buttons, element);
const dt = settings.oInstance.api();

events.one('output_appended.OutputArea', () => dt.columns.adjust());

console.debug("DataTable successfully created.");
"""

execute_with_requirements(
    script,
    required=["base/js/events", "datatables.net", "d3", "jupyter-datatables"],
    html=html,
    options=json.dumps(options),
    buttons=buttons,
)

# return script which links the scrollbars event after save
