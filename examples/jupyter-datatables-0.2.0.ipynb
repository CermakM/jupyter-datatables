# %% [markdown]
# # Jupyter DataTables 0.2.0
#
# <br>
#
# ### New features:
#
# - histogram, bar and timeseries plots
# - string and date support
# - automatic binning for histograms
# - display original dtype along with the data preview

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import string

import numpy as np
import pandas as pd

# %%
from jupyter_datatables import init_datatables_mode

# %%
# %reload_ext jupyter_require
# %reload_ext jupyter_tools

# %%
init_datatables_mode()

# %% [markdown]
# ---

# %% [markdown]
# ## Data

# %%
df      = pd.DataFrame(np.random.randn(50, 6), columns=list(string.ascii_uppercase[:6]))
df_long = pd.DataFrame(np.random.randn(int(1e5), 6), columns=list(string.ascii_uppercase[:6]))
df_wide = pd.DataFrame(np.random.randn(50, 20), columns=list(string.ascii_uppercase[:20]))

labels = ["{0} - {1}".format(i, i + 9) for i in range(0, 100, 10)]
df_categorical = pd.DataFrame({'value': np.random.randint(0, 100, 20)})
df_categorical['group'] = pd.cut(df_categorical.value, range(0, 105, 10), right=False, labels=labels)

# %%
dft = pd.DataFrame({'A': np.random.rand(5),
                    'B': [1, 1, 3, 2, 1],
                    'C': 'foo',
                    'C_': 'This is a very long sentence that should automatically be trimmed',
                    'D': [pd.Timestamp('20010101'), pd.Timestamp('20010102'), pd.Timestamp('20010103'), pd.Timestamp('20010103'), pd.Timestamp('20010104')],
                    'E': pd.Series([1.0] * 5).astype('float32'),
                    'F': [False, True, False, False, True],
                    'G': pd.Series([1] * 5, dtype='int8')}
                  )

# %% [markdown]
# ---

# %% [markdown]
# ## Representation

# %%
df
# Out:
# <div id="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d_length"><label>Show <select name="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d_length" aria-controls="5fe386a86d29d4a7fe0629c5ce5350df960f9d1ad7af06feefab8423f633ba0d" class="">
# ...

# %%
df_long
# Out:
# <div id="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4_length"><label>Show <select name="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4_length" aria-controls="98b2392821e270a9518dbd2dbc83387e910186b8ac4a4910866d019368f4c2a4" class="">
# ...

# %%
df_wide
# Out:
# <div id="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b_length"><label>Show <select name="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b_length" aria-controls="471d4ede4d3b224b8655cd63d7c759d6df940290cbbff6de5c3811e5cab3459b" class="">
# ...

# %% [markdown]
# ## Various DTypes and distributions
#
# Plots are automatically chosen based on the data type and the distribution of the data.
#
# | DType  | Size | Type of plot
# | --- | --- | --- |
# | numerical | small | bar |
# | numerical | big   | histogram |
# | object | small / big | bar |
# | timeseries  | small / big | line |

# %%
dft
# Out:
# <div id="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print" tabindex="0" aria-controls="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c" type="button"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5" tabindex="0" aria-controls="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c" type="button"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5" tabindex="0" aria-controls="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c" type="button"><span>PDF</span></button> </div><div class="dataTables_length" id="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c_length"><label>Show <select name="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c_length" aria-controls="a114c088ff66743d1659bd57091e08ba76e8ceffd142c0840e3eb505a1656e7c" class="">
# ...

# %% [markdown]
# ---
